# %% [markdown]
# # 06-clonotype-clustering

# %%
import scanpy as sc
import scirpy as ir
import numpy as np
import json
from pathlib import Path
import pandas as pd
import muon as mu
import anndata as ad
import gzip
import shutil
from concurrent.futures import ThreadPoolExecutor
import matplotlib.cm as mpl_cm
from cycler import cycler
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

DATA = Path("data")

N_SAMPLES = [
  "LN1",
  "LN2",
  "LN3",
  "LN4",
  "LN5",
  "LN6",
  "EN1",
  "EN2",
  "EN3",
  "CN1",
  "CN2",
  "RN1",
  "RN2",
  "RN3",
]

T_SAMPLES = [
  "LT1",
  "LT2",
  "LT3",
  "LT4",
  "LT5",
  "LT6",
  "ET1",
  "ET2",
  "ET3",
  "CT1",
  "CT2",
  "RT1",
  "RT2",
  "RT3",
]

B_SAMPLES = [
  "LB6",
  "RB1",
  "RB2",
  "RB3",
]

SAMPLES = N_SAMPLES + T_SAMPLES + B_SAMPLES

def sample_tissue(sample: str) -> str:
  if sample in B_SAMPLES:
    return "Blood"
  if sample in N_SAMPLES:
    return "Normal"
  if sample in T_SAMPLES:
    return "Tumor"
  raise ValueError(f"Unknown sample: {sample}")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# /Users/alegator1209/micromamba/envs/pytcr/lib/python3.10/site-packages/muon/_core/preproc.py:31: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('scanpy')` instead
#   if Version(scanpy.__version__) < Version("1.10"):

# %%
def extract_file(path: Path) -> Path:
  extracted = Path(str(path).partition(".gz")[0])

  with gzip.open(path, 'rb') as f_in:
    with open(extracted, 'wb') as f_out:
      shutil.copyfileobj(f_in, f_out)

  return extracted

def extract_mtx_data(dir: Path, prefix: str):
  extract_file(dir / f"{prefix}barcodes.tsv.gz")
  extract_file(dir / f"{prefix}genes.tsv.gz")
  extract_file(dir / f"{prefix}matrix.mtx.gz")

# %%
def find_prefix(dir: Path) -> str:
  matches = list(dir.glob("*barcodes.tsv.gz"))
  if len(matches) != 1:
    raise ValueError(f"Expected exactly one barcodes.tsv.gz file in {dir}, found {len(matches)}")
  return matches[0].name.removesuffix("barcodes.tsv.gz")

def read_sample(dir: Path) -> mu.MuData:
  print(f"Reading sample {dir.name}")
  prefix = find_prefix(dir)
  extract_mtx_data(dir, prefix)

  adata = sc.read_10x_mtx(dir, prefix=prefix)
  adata.var_names_make_unique()
  adata_tcr = ir.io.read_10x_vdj(dir / f"{prefix}filtered_contig_annotations.csv.gz")

  mdata = mu.MuData({'gex': adata, 'airr': adata_tcr})
  mdata['gex'].obs['sample'] = dir.name
  mdata['gex'].obs['source'] = sample_tissue(dir.name)
  mdata.update()

  return mdata

# %%
with ThreadPoolExecutor(max_workers=8) as executor:
  samples = list(executor.map(lambda s: read_sample(DATA / s), SAMPLES))
# Out:
# Reading sample LN1Reading sample LN2
#
# Reading sample LN3
# Reading sample LN4
# Reading sample LN5
# Reading sample LN6
# Reading sample EN1
# Reading sample EN2
# WARNING: Non-standard locus name: Multi
# Reading sample EN3
# WARNING: Non-standard locus name: Multi
# WARNING: Non-standard locus name: None
# Reading sample CN1
# WARNING: Non-standard locus name: None
# WARNING: Non-standard locus name: Multi
# Reading sample CN2
# WARNING: Non-standard locus name: Multi
# WARNING: Non-standard locus name: None
# Reading sample RN1
# WARNING: Non-standard locus name: None
# WARNING: Non-standard locus name: Multi
# Reading sample RN2
# WARNING: Non-standard locus name: Multi
# WARNING: Non-standard locus name: None
# Reading sample RN3
# WARNING: Non-standard locus name: Multi
# WARNING: Non-standard locus name: None
# Reading sample LT1
# WARNING: Non-standard locus name: Multi
# WARNING: Non-standard locus name: None
# WARNING: Non-standard locus name: Multi
# WARNING: Non-standard locus name: None
# Reading sample LT2
# Reading sample LT3
# WARNING: Non-standard locus name: Multi
# WARNING: Non-standard locus name: None
# WARNING: Non-standard locus name: Multi
# WARNING: Non-standard locus name: None
# Reading sample LT4
# WARNING: Non-standard locus name: Multi
# WARNING: Non-standard locus name: None
# Reading sample LT5
# Reading sample LT6
# WARNING: Non-standard locus name: Multi
# WARNING: Non-standard locus name: None
# Reading sample ET1
# WARNING: Non-standard locus name: None
# WARNING: Non-standard locus name: Multi
# WARNING: Non-standard locus name: Multi
# WARNING: Non-standard locus name: None
# WARNING: Non-standard locus name: Multi
# WARNING: Non-standard locus name: None
# Reading sample ET2
# Reading sample ET3
# Reading sample CT1
# WARNING: Non-standard locus name: Multi
# WARNING: Non-standard locus name: None
# Reading sample CT2
# WARNING: Non-standard locus name: Multi
# WARNING: Non-standard locus name: None
# WARNING: Non-standard locus name: None
# WARNING: Non-standard locus name: Multi
# Reading sample RT1
# WARNING: Non-standard locus name: Multi
# Reading sample RT2
# WARNING: Non-standard locus name: Multi
# WARNING: Non-standard locus name: None
# WARNING: Non-standard locus name: Multi
# WARNING: Non-standard locus name: None
# WARNING: Non-standard locus name: Multi
# Reading sample RT3
# WARNING: Non-standard locus name: None
# Reading sample LB6
# Reading sample RB1
# Reading sample RB2
# WARNING: Non-standard locus name: Multi
# WARNING: Non-standard locus name: None
# Reading sample RB3
# WARNING: Non-standard locus name: Multi
# WARNING: Non-standard locus name: None
# WARNING: Non-standard locus name: Multi
# WARNING: Non-standard locus name: Multi
# WARNING: Non-standard locus name: None
# WARNING: Non-standard locus name: Multi
# WARNING: Non-standard locus name: None
# WARNING: Non-standard locus name: Multi
# WARNING: Non-standard locus name: None
# WARNING: Non-standard locus name: Multi
# WARNING: Non-standard locus name: None
# WARNING: Non-standard locus name: Multi
# WARNING: Non-standard locus name: None
# WARNING: Non-standard locus name: Multi
# WARNING: Non-standard locus name: None

# %%
def preprocess(sample: mu.MuData) -> mu.MuData:
  sc.pp.filter_genes(sample["gex"], min_cells=10)
  sc.pp.filter_cells(sample["gex"], min_genes=100)
  return sample

def integrate(samples: list[mu.MuData]) -> mu.MuData:
  gex = ad.concat(
    {s.obs["gex:sample"].iloc[0]: s["gex"] for s in samples},
    index_unique='-',
    join='outer',
  )

  airr = ad.concat(
    {s.obs["gex:sample"].iloc[0]: s["airr"] for s in samples},
    index_unique='-',
    join='outer',
  )

  mdata = mu.MuData({'gex': gex, 'airr': airr})
  mu.pp.intersect_obs(mdata)
  mdata.update()
  return mdata

# %%
samples = [preprocess(s) for s in samples]
mdata = integrate(samples)
mdata
# Out:
# MuData object with n_obs × n_vars = 110365 × 17474
#   2 modalities
#     gex:	110365 × 17474
#       obs:	'sample', 'source', 'n_genes'
#     airr:	110365 × 0
#       obsm:	'airr'

# %%
sc.pp.normalize_per_cell(mdata["gex"])
sc.pp.log1p(mdata["gex"])
sc.pp.highly_variable_genes(mdata["gex"], flavor="cell_ranger", n_top_genes=5000)
sc.tl.pca(mdata["gex"])
sc.pp.neighbors(mdata["gex"])
sc.tl.umap(mdata["gex"])
mdata.update()
mdata
# Out:
# MuData object with n_obs × n_vars = 110365 × 17474
#   2 modalities
#     gex:	110365 × 17474
#       obs:	'sample', 'source', 'n_genes', 'n_counts'
#       var:	'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#       uns:	'log1p', 'hvg', 'pca', 'neighbors', 'umap'
#       obsm:	'X_pca', 'X_umap'
#       varm:	'PCs'
#       obsp:	'distances', 'connectivities'
#     airr:	110365 × 0
#       obsm:	'airr'

# %%
mu.pl.embedding(
  mdata,
  basis="gex:umap",
  color=["gex:sample"],
  ncols=3,
  wspace=0.7,
)

# %%
ir.pp.index_chains(mdata)
ir.tl.chain_qc(mdata)

# %%
mdata['airr'].obs.groupby('receptor_subtype').count()
# Out:
#                   receptor_type  chain_pairing
# receptor_subtype
# IGH                         110            110
# IGH+IGK                      10             10
# TRA+TRB                   99268          99268
# TRG+TRD                       1              1
# ambiguous                     2              2
# multichain                  499            499
# no IR                     10475          10475

# %%
mu.pl.embedding(
  mdata,
  basis="gex:umap",
  color=["airr:receptor_subtype"],
  ncols=3,
  wspace=0.7,
)

# %%
mu.pp.filter_obs(mdata, "airr:receptor_subtype", lambda x: x == "TRA+TRB")

# %%
mu.pl.embedding(
  mdata,
  basis="gex:umap",
  color=["airr:receptor_subtype"],
  ncols=3,
  wspace=0.7,
)

# %%
mu.pp.filter_obs(mdata, "airr:chain_pairing", lambda x: ~np.isin(x, ["no IR", "orphan VDJ", "orphan VJ", "multichain"]))

# %%
mdata.obs.groupby("airr:chain_pairing").count()
# Out:
#                     gex:sample  gex:source  gex:n_genes  gex:n_counts  \
# airr:chain_pairing
# extra VDJ                 2499        2499         2499          2499
# extra VJ                  3402        3402         3402          3402
# single pair              55319       55319        55319         55319
# two full chains            750         750          750           750
#
#                     airr:receptor_type  airr:receptor_subtype
# airr:chain_pairing
# extra VDJ                         2499                   2499
# extra VJ                          3402                   3402
# single pair                      55319                  55319
# two full chains                    750                    750

# %%
ir.pp.ir_dist(mdata)
ir.tl.define_clonotypes(mdata, receptor_arms="all", dual_ir="primary_only")
ir.tl.clonotype_network(mdata, min_cells=3)
ir.pp.ir_dist(
    mdata,
    metric="tcrdist",
    sequence="aa",
    cutoff=15,
)
ir.tl.define_clonotype_clusters(mdata, sequence="aa", metric="tcrdist", receptor_arms="all", dual_ir="any")
ir.tl.clonotype_network(mdata, min_cells=3, sequence="aa", metric="tcrdist")

# %%
mdata.obs.groupby("gex:source", dropna=False).size()
# Out:
# gex:source
# Blood      4146
# Normal    24933
# Tumor     32891
# dtype: int64

# %%
ir.tl.clonotype_modularity(mdata, target_col="airr:cc_aa_tcrdist")
# Out:
#   0%|          | 0/31397 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
mu.pl.embedding(mdata, basis="gex:umap", color="airr:clonotype_modularity")

# %%
obs = mdata.obs
obs = obs[obs['gex:sample']  == "ET3"]
et3_mean_modularity = obs['airr:clonotype_modularity'].mean()
print(f"ET3 mean clonotype modularity: {et3_mean_modularity}")
# Out:
# ET3 mean clonotype modularity: 1.1692090780439102

# %%
blood_mdata = mdata[mdata.obs["gex:source"] == "Blood"].copy()

ir.pl.clonotype_modularity(blood_mdata, base_size=20)
# Out:
# <Axes: xlabel='modularity score', ylabel='-log10(FDR)'>

# %%
clonotypes_top_modularity = list(
    blood_mdata.obs.set_index("airr:cc_aa_tcrdist")["airr:clonotype_modularity"]
    .sort_values(ascending=False)
    .index.unique()
    .values[:1]
)

clonotypes_top_modularity
# Out:
# ['10331']

# %%
obs = blood_mdata.obs
obs = obs[['airr:cc_aa_tcrdist', 'airr:clonotype_modularity', 'airr:clonotype_modularity_fdr']]
obs = obs.groupby('airr:cc_aa_tcrdist').mean()

clonotype = obs[obs.index == clonotypes_top_modularity[0]]
top_modularity_score = clonotype['airr:clonotype_modularity'].item()
top_pval = clonotype['airr:clonotype_modularity_fdr'].item()

print(f"Top 1 clonotype cluster modularity score (p-val): {top_modularity_score} ({top_pval})")
# Out:
# Top 1 clonotype cluster modularity score (p-val): 7.0438664705576715 (2.4441719293223418e-36)

# %%
test_ad = mu.pl.embedding(
    mdata,
    basis="gex:umap",
    color="airr:cc_aa_tcrdist",
    groups=clonotypes_top_modularity,
    palette=cycler(color=mpl_cm.Dark2_r.colors),
)

# %%
with ir.get.obs_context(mdata["gex"], {"cc_aa_tcrdist": mdata.obs["airr:cc_aa_tcrdist"]}) as tmp_ad:
    sc.tl.rank_genes_groups(
        tmp_ad,
        "cc_aa_tcrdist",
        groups=clonotypes_top_modularity,
        reference="rest",
        method="wilcoxon",
    )
    fig, ax = plt.subplots(1, 1, figsize=(8, 4))
    sc.pl.rank_genes_groups_violin(tmp_ad, groups=[clonotypes_top_modularity[0]], n_genes=15, ax=ax, show=False, strip=False)

# %%
freq, stat = ir.tl.clonotype_imbalance(
  mdata,
  replicate_col="gex:sample",
  groupby="gex:source",
  case_label="Tumor",
  control_label="Normal",
  inplace=False,
)
top_differential_clonotypes = stat["clone_id"].tolist()[:3]
# Out:
# WARNING: Clonotype imbalance calculation depends on repertoire overlap. We could not detect any previous runs of repertoire_overlap, so the tool is running now...

# %%
top_differential_clonotypes
# Out:
# ['2', '26689', '1379']

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4), gridspec_kw={"wspace": 0.6})
mu.pl.embedding(mdata, basis="gex:umap", color="gex:source", ax=ax1, show=False)
mu.pl.embedding(
    mdata,
    basis="gex:umap",
    color="airr:clone_id",
    groups=top_differential_clonotypes,
    ax=ax2,
    size=[
        80 if c in top_differential_clonotypes else 30 for c in mdata.obs["airr:clone_id"][mdata.mod["gex"].obs_names]
    ],
    palette=cycler(color=mpl_cm.Dark2_r.colors),
)

# %%
output = {
  "et3_mean_modularity": et3_mean_modularity,
  "top_modularity_score": top_modularity_score,
  "top_pval": top_pval,
  "top_expression_FGFPB2": "less",
  "n_tumor_differential_clonotypes": 2
}

print(json.dumps(output, indent=2))

# with open('output.json', 'w') as f:
#     json.dump(output, f, indent=2)
# print('Results saved to output.json:')
# Out:
# {
#   "et3_mean_modularity": 1.1692090780439102,
#   "top_modularity_score": 7.0438664705576715,
#   "top_pval": 2.4441719293223418e-36,
#   "top_expression_FGFPB2": "less",
#   "n_tumor_differential_clonotypes": 2
# }
